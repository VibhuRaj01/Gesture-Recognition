# %%
# !nvidia-smi

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel

# %%
# !pip install -q roboflow ultralytics --use-deprecated=legacy-resolver

# %%
from roboflow import Roboflow

rf = Roboflow(api_key=APIKEY)
project = rf.workspace("abdul-mannan").project("thumbs-p8zym")
version = project.version(7)
dataset = version.download("yolov9")

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
results = model.train(data='/kaggle/input/d/vibhuraj01/dataset/data.yaml', epochs=50, imgsz=512, device=0)

# %%
# !zip -r file.zip '/kaggle/working/runs/detect/train2'
